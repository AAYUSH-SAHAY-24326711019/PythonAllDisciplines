# %%
# we will use the matplotlib for the data visualization.

# %%
# for the purpose to analyze the large data to be analyzed by a graph
#  we can fulfil our requirements. 
# Represent the data : quickly
# chart graphs maps

# %%
#  mat plot lib will plot the data 2d or 3d manner

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# from matplotlib import pyplot as plt
