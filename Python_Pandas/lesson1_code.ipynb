# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# pandas is a statistical library for the purpose for decision making
# applicable to many fields.

# %%
import pandas as pd

# %%
pd.__version__ #know the version
# Out:
# '2.2.3'

# %%
# series is similar to a list , single column table is series
# dataframe is similar to a relation / table /matrix but of a simgle columns.

# %%
sales = pd.Series([2,3,4])
print(sales,type(sales),sales.dtype)
# Out:
# 0    2
# 1    3
# 2    4
# dtype: int64 <class 'pandas.core.series.Series'> int64

# %%
# print using the index
print(sales[0])

sales[0]
# Out:
# 2
# np.int64(2)

# %%
sales[0:2] #this is the slicing from the series
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
sales.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
sales.values
type(sales.values)
# Out:
# numpy.ndarray

# %%
sales.head(1)  #from how many number of samples you want to see.
# Out:
# 0    2
# dtype: int64

# %%
# from the end 2 rows:

sales.tail(2)
# Out:
# 1    3
# 2    4
# dtype: int64

# %%
sales = pd.Series([5,6,7,8,1,2,4,9])
print(sales.sort_values())
# Out:
# 4    1
# 5    2
# 6    4
# 0    5
# 1    6
# 2    7
# 3    8
# 7    9
# dtype: int64

# %%
sales.count() #tell the count
# Out:
# np.int64(8)

# %%
sales.notnull()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5    True
# 6    True
# 7    True
# dtype: bool

# %%
sales + 2 #add 2 to all the values
# Out:
# 0     7
# 1     8
# 2     9
# 3    10
# 4     3
# 5     4
# 6     6
# 7    11
# dtype: int64

# %%
# do the square of all the values and show them as sorted
(sales **2).sort_values()
# Out:
# 4     1
# 5     4
# 6    16
# 0    25
# 1    36
# 2    49
# 3    64
# 7    81
# dtype: int64

# %%
sales_missing = pd.Series([2,None,5])
sales_missing
# Out:
# 0    2.0
# 1    NaN
# 2    5.0
# dtype: float64

# %%
#to fill the nan with 0
sales_missing=sales_missing.fillna(0)
sales_missing
# Out:
# 0    2.0
# 1    0.0
# 2    5.0
# dtype: float64

# %%
#default indexes 0,1,2,3
#making user custom indeses

marks = pd.Series([50,55,78,95,65,32,10,25,45],index=list('abcdefghi'))
marks
# Out:
# a    50
# b    55
# c    78
# d    95
# e    65
# f    32
# g    10
# h    25
# i    45
# dtype: int64
