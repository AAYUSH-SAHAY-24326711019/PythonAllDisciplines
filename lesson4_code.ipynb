# %%
'''Short circuit evaluation

we will make the use of and , or
we will see that python has a problem
it will not evaluate the logical expressions completely
it will exit once the primary condition is true
without caring for the later conditions
'''

# %%
#eg.
a=0
b=10
result = (a!=0) or (b%2==a)
print(result)
# Out:
# True

# %%
#print the raw strings, this comes into play when
#there is need to show the locations

print(r"~/home/kali/Desktop")
# Out:
# ~/home/kali/Desktop

# %%
#use the print function to write to a file
new_file = open("temp\log.txt","w") # use \ in python for /
print("Date : 07/02/2026 name: Aayush", file=new_file)
new_file.close()
# inside file log.txt
#Date : 07/02/2026 name: Aayush
